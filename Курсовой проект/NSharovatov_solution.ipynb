# %% [markdown]
# # Курсовой проект по курсу "Библиотеки Python для Data Science"

# %% [markdown]
# ### Подключение библиотек

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import norm
from scipy import stats

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Пути к директориям и файлам

# %%
TRAIN_DATASET_PATH = 'train.csv'
TEST_DATASET_PATH = 'test.csv'

# %% [markdown]
# ## Загрузка данных

# %% [markdown]
# **Описание датасета:**
#
# * **Id** - идентификационный номер квартиры
# * **DistrictId** - идентификационный номер района
# * **Rooms** - количество комнат
# * **Square** - площадь
# * **LifeSquare** - жилая площадь
# * **KitchenSquare** - площадь кухни
# * **Floor** - этаж
# * **HouseFloor** - количество этажей в доме
# * **HouseYear** - год постройки дома
# * **Ecology_1, Ecology_2, Ecology_3** - экологические показатели местности
# * **Social_1, Social_2, Social_3** - социальные показатели местности
# * **Healthcare_1, Helthcare_2** - показатели местности, связанные с охраной здоровья
# * **Shops_1, Shops_2** - показатели, связанные с наличием магазинов, торговых центров
# * **Price** - цена квартиры - целивая переменная

# %%
train = pd.read_csv(TRAIN_DATASET_PATH)
test = pd.read_csv(TEST_DATASET_PATH)

# %%
print(f'Train:\tКоличество наблюдений - {train.shape[0]}\tКоличество признаков - {train.shape[1]}')
print(f'Test:\tКоличество наблюдений - {test.shape[0]}\tКоличество признаков - {test.shape[1]}')
# Out:
# Train:	Количество наблюдений - 10000	Количество признаков - 20
# Test:	Количество наблюдений - 5000	Количество признаков - 19

# %%
train.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0  14038          35    2.0  47.981561   29.442751            6.0      7
# 1  15053          41    3.0  65.683640   40.049543            8.0      7
# 2   4765          53    2.0  44.947953   29.197612            0.0      8
# 3   5809          58    2.0  53.352981   52.731512            9.0      8
# 4  10783          99    1.0  39.649192   23.776169            7.0     11
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0         9.0       1969   0.089040         B         B        33      7976
# 1         9.0       1978   0.000070         B         B        46     10309
# 2        12.0       1968   0.049637         B         B        34      7759
# 3        17.0       1977   0.437885         B         B        23      5735
# 4        12.0       1976   0.012339         B         B        35      5776
#
#    Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2          Price
# 0         5           NaN            0       11       B  184966.930730
# 1         1         240.0            1       16       B  300009.450063
# 2         0         229.0            1        3       B  220925.908524
# 3         3        1084.0            0        5       B  175616.227217
# 4         1        2078.0            2        4       B  150226.531644

# %%
test.head()
# Out:
#       Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0    725          58    2.0  49.882643   33.432782            6.0      6
# 1  15856          74    2.0  69.263183         NaN            1.0      6
# 2   5480         190    1.0  13.597819   15.948246           12.0      2
# 3  15664          47    2.0  73.046609   51.940842            9.0     22
# 4  14275          27    1.0  47.527111   43.387569            1.0     17
#
#    HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  Social_2  \
# 0        14.0       1972   0.310199         B         B        11      2748
# 1         1.0       1977   0.075779         B         B         6      1437
# 2         5.0       1909   0.000000         B         B        30      7538
# 3        22.0       2007   0.101872         B         B        23      4583
# 4        17.0       2017   0.072158         B         B         2       629
#
#    Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 0         1           NaN            0        0       B
# 1         3           NaN            0        2       B
# 2        87        4702.0            5        5       B
# 3         3           NaN            3        3       B
# 4         1           NaN            0        0       A

# %%
train.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             10000 non-null  int64
#  1   DistrictId     10000 non-null  int64
#  2   Rooms          10000 non-null  float64
#  3   Square         10000 non-null  float64
#  4   LifeSquare     7887 non-null   float64
#  5   KitchenSquare  10000 non-null  float64
#  6   Floor          10000 non-null  int64
#  7   HouseFloor     10000 non-null  float64
#  8   HouseYear      10000 non-null  int64
#  9   Ecology_1      10000 non-null  float64
#  10  Ecology_2      10000 non-null  object
#  11  Ecology_3      10000 non-null  object
#  12  Social_1       10000 non-null  int64
#  13  Social_2       10000 non-null  int64
#  14  Social_3       10000 non-null  int64
#  15  Healthcare_1   5202 non-null   float64
#  16  Helthcare_2    10000 non-null  int64
#  17  Shops_1        10000 non-null  int64
#  18  Shops_2        10000 non-null  object
#  19  Price          10000 non-null  float64
# dtypes: float64(8), int64(9), object(3)
# memory usage: 3.1 MB

# %%
test.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             5000 non-null   int64
#  1   DistrictId     5000 non-null   int64
#  2   Rooms          5000 non-null   float64
#  3   Square         5000 non-null   float64
#  4   LifeSquare     3959 non-null   float64
#  5   KitchenSquare  5000 non-null   float64
#  6   Floor          5000 non-null   int64
#  7   HouseFloor     5000 non-null   float64
#  8   HouseYear      5000 non-null   int64
#  9   Ecology_1      5000 non-null   float64
#  10  Ecology_2      5000 non-null   object
#  11  Ecology_3      5000 non-null   object
#  12  Social_1       5000 non-null   int64
#  13  Social_2       5000 non-null   int64
#  14  Social_3       5000 non-null   int64
#  15  Healthcare_1   2623 non-null   float64
#  16  Helthcare_2    5000 non-null   int64
#  17  Shops_1        5000 non-null   int64
#  18  Shops_2        5000 non-null   object
# dtypes: float64(7), int64(9), object(3)
# memory usage: 1.5 MB

# %% [markdown]
# ### Вынужденная оптимизация использования памяти (имею старенькую машину)

# %%
def optimizing_df(df):
    for col in df.columns:
        if df[col].dtypes.kind == 'i' or df[col].dtypes.kind == 'u':
            if df[col].min() >= 0:
                df[col] = pd.to_numeric(df[col], downcast='unsigned')
            else:
                df[col] = pd.to_numeric(df[col], downcast='integer')

        elif df[col].dtypes.kind == 'f' or df[col].dtypes.kind == 'c':
            df[col] = pd.to_numeric(df[col], downcast='float')

        elif df[col].dtypes.kind == 'O':
            num_unique_values = len(df[col].unique())
            num_total_values = len(df[col])
            if num_unique_values / num_total_values < 0.5:
                df[col] = df[col].astype('category')

    return df

# %%
train['Rooms'] = train['Rooms'].astype('int64')
test['Rooms'] = test['Rooms'].astype('int64')

# %%
train['HouseFloor'] = train['HouseFloor'].astype('int64')
test['HouseFloor'] = test['HouseFloor'].astype('int64')

# %%
train = optimizing_df(train)
test = optimizing_df(test)

# %%
train.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             10000 non-null  uint16
#  1   DistrictId     10000 non-null  uint8
#  2   Rooms          10000 non-null  uint8
#  3   Square         10000 non-null  float32
#  4   LifeSquare     7887 non-null   float32
#  5   KitchenSquare  10000 non-null  float32
#  6   Floor          10000 non-null  uint8
#  7   HouseFloor     10000 non-null  uint8
#  8   HouseYear      10000 non-null  uint32
#  9   Ecology_1      10000 non-null  float32
#  10  Ecology_2      10000 non-null  category
#  11  Ecology_3      10000 non-null  category
#  12  Social_1       10000 non-null  uint8
#  13  Social_2       10000 non-null  uint16
#  14  Social_3       10000 non-null  uint8
#  15  Healthcare_1   5202 non-null   float32
#  16  Helthcare_2    10000 non-null  uint8
#  17  Shops_1        10000 non-null  uint8
#  18  Shops_2        10000 non-null  category
#  19  Price          10000 non-null  float32
# dtypes: category(3), float32(6), uint16(2), uint32(1), uint8(8)
# memory usage: 420.6 KB

# %%
test.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             5000 non-null   uint16
#  1   DistrictId     5000 non-null   uint8
#  2   Rooms          5000 non-null   uint8
#  3   Square         5000 non-null   float32
#  4   LifeSquare     3959 non-null   float32
#  5   KitchenSquare  5000 non-null   float32
#  6   Floor          5000 non-null   uint8
#  7   HouseFloor     5000 non-null   uint8
#  8   HouseYear      5000 non-null   uint16
#  9   Ecology_1      5000 non-null   float32
#  10  Ecology_2      5000 non-null   category
#  11  Ecology_3      5000 non-null   category
#  12  Social_1       5000 non-null   uint8
#  13  Social_2       5000 non-null   uint16
#  14  Social_3       5000 non-null   uint8
#  15  Healthcare_1   2623 non-null   float32
#  16  Helthcare_2    5000 non-null   uint8
#  17  Shops_1        5000 non-null   uint8
#  18  Shops_2        5000 non-null   category
# dtypes: category(3), float32(5), uint16(3), uint8(8)
# memory usage: 181.4 KB

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Объединяем датафреймы 'train' и 'test'

# %%
all_data = pd.concat((train, test), sort=False).reset_index(drop=True)
all_data.drop(['Price'], axis=1, inplace=True)

all_data.shape
# Out:
# (15000, 19)

# %%
all_data.describe().T
# Out:
#                  count         mean            std          min          25%  \
# Id             15000.0  8393.136933    4850.111673     0.000000  4188.750000
# DistrictId     15000.0    50.693600      43.786257     0.000000    20.000000
# Rooms          15000.0     1.897000       0.839229     0.000000     1.000000
# Square         15000.0    56.360546      20.423899     1.136859    41.814370
# LifeSquare     11846.0    36.851711      71.120201     0.333490    22.896130
# KitchenSquare  15000.0     6.174467      24.017548     0.000000     1.000000
# Floor          15000.0     8.561800       5.323113     1.000000     4.000000
# HouseFloor     15000.0    12.606600       6.780165     0.000000     9.000000
# HouseYear      15000.0  3321.575067  163707.780381  1908.000000  1974.000000
# Ecology_1      15000.0     0.119195       0.119371     0.000000     0.017647
# Social_1       15000.0    24.769267      17.532278     0.000000     6.000000
# Social_2       15000.0  5370.404933    4013.364403   168.000000  1564.000000
# Social_3       15000.0     8.113667      23.841946     0.000000     0.000000
# Healthcare_1    7825.0  1144.162476    1029.307373     0.000000   350.000000
# Helthcare_2    15000.0     1.319467       1.489012     0.000000     0.000000
# Shops_1        15000.0     4.235133       4.796545     0.000000     1.000000
#
#                        50%           75%           max
# Id             8378.500000  12594.250000  1.679800e+04
# DistrictId       37.000000     75.000000  2.120000e+02
# Rooms             2.000000      2.000000  1.900000e+01
# Square           52.645758     66.036606  6.410652e+02
# LifeSquare       32.822811     45.144627  7.480592e+03
# KitchenSquare     6.000000      9.000000  2.014000e+03
# Floor             7.000000     12.000000  7.800000e+01
# HouseFloor       12.000000     17.000000  1.170000e+02
# HouseYear      1977.000000   2001.000000  2.005201e+07
# Ecology_1         0.075424      0.195781  5.218670e-01
# Social_1         25.000000     36.000000  7.400000e+01
# Social_2       5285.000000   7287.000000  1.908300e+04
# Social_3          2.000000      5.000000  1.410000e+02
# Healthcare_1    900.000000   1548.000000  4.849000e+03
# Helthcare_2       1.000000      2.000000  6.000000e+00
# Shops_1           3.000000      6.000000  2.300000e+01

# %% [markdown]
# ### Исследуем пропуски

# %%
def df_explore_missing(df):   
    missing_df = df.isnull().sum(axis=0).reset_index()
    missing_df.columns = ['column_name', 'missing_count']
    missing_df = missing_df[missing_df['missing_count']>0]
    missing_df = missing_df.sort_values(by='missing_count')
    
    ind = np.arange(missing_df.shape[0])
    fig, ax = plt.subplots(figsize=(10, 1))
    rects = ax.barh(ind, missing_df.missing_count.values, color='b')
    ax.set_yticks(ind)
    ax.set_yticklabels(missing_df.column_name.values, rotation='horizontal')
    ax.set_xlabel(f'Count of missing values  (count of observations - {len(df)})')
    ax.set_title('Number of missing values in each column', loc='left')
    plt.grid(axis='x', color='w')
    plt.show()

# %%
df_explore_missing(all_data)

# %% [markdown]
# Судя по полученным результатам с признаком 'LifeSquare' будем работать дальше, а признак 'Healthcare_1' будем удалять (почти 50% пропусков)

# %% [markdown]
# ## Обработка выбросов

# %% [markdown]
# ### Работаем с признаком 'Rooms'

# %%
all_data.loc[all_data['Rooms'] > 6]
# Out:
#           Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 377     5927          57     10  59.056976   36.223072           10.0     22
# 1454    8491           1     19  42.006046   21.779287            7.0     17
# 8849   14865           9     10  60.871265   38.420681           10.0      3
# 13398   1435         111     17  52.866108   32.528343            8.0     15
#
#        HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 377            22       2002   0.090799         B         B        74
# 1454           17       2014   0.007122         B         B         1
# 8849            2       1994   0.161532         B         B        25
# 13398          17       1987   0.093443         B         B        23
#
#        Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 377       19083         2           NaN            5       15       B
# 1454        264         0           NaN            0        1       B
# 8849       5648         1          30.0            2        4       B
# 13398      4635         5        3300.0            2        4       B

# %%
all_data.loc[all_data['Rooms'] == 0]
# Out:
#           Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 1397   12638          27      0  138.427689  136.215500            0.0      4
# 1981    7917          27      0  212.932358  211.231125            0.0      2
# 2269    7317          27      0   41.790882         NaN            0.0     13
# 3911     770          28      0   49.483501         NaN            0.0     16
# 4366     456           6      0   81.491447         NaN            0.0      4
# 4853    3224          27      0    2.377248    0.873147            0.0      1
# 6149    3159          88      0   38.697117   19.345131            9.0      9
# 8834    9443          27      0   87.762619   85.125473            0.0      5
# 12406   3343          58      0  116.824203  113.692421            0.0      3
# 12524  10729          27      0   76.345154   42.820797           12.0     14
#
#        HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1397            3       2016   0.075424         B         B        11
# 1981            3       2008   0.211401         B         B         9
# 2269            0       1977   0.211401         B         B         9
# 3911            0       2015   0.118537         B         B        30
# 4366            0       1977   0.243205         B         B         5
# 4853            0       1977   0.017647         B         B         2
# 6149           16       1982   0.127376         B         B        43
# 8834           15       1977   0.211401         B         B         9
# 12406           3       1977   0.437885         B         B        23
# 12524           0       1977   0.017647         B         B         2
#
#        Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 1397       3097         0           NaN            0        0       B
# 1981       1892         0           NaN            0        1       B
# 2269       1892         0           NaN            0        1       B
# 3911       6207         1        1183.0            1        0       B
# 4366       1564         0         540.0            0        0       B
# 4853        469         0           NaN            0        0       B
# 6149       8429         3           NaN            3        9       B
# 8834       1892         0           NaN            0        1       B
# 12406      5735         3        1084.0            0        5       B
# 12524       469         0           NaN            0        0       B

# %%
def df_fix_room(df):
    info_by_district_id = df.groupby(['DistrictId', 'HouseYear'], as_index=False).agg(
        {'Rooms': 'sum', 'Square': 'sum'}).rename(
        columns={'Rooms': 'sum_roos_dr', 'Square': 'sum_square_dr'})

    info_by_district_id['mean_square_per_room_in_dr'] = info_by_district_id['sum_square_dr'] \
        / info_by_district_id['sum_roos_dr']
    info_by_district_id.drop(
        ['sum_square_dr', 'sum_roos_dr'], axis=1, inplace=True)

    df = pd.merge(df, info_by_district_id, on=[
                  'DistrictId', 'HouseYear'], how='left')

    df['mean_square_per_room_in_dr'] = df['mean_square_per_room_in_dr'].fillna(
        df['mean_square_per_room_in_dr'].mean())

    df.loc[df['Rooms'] > 6, 'Rooms'] \
        = (df.loc[df['Rooms'] > 6, 'Square']
           // df.loc[df['Rooms'] > 6, 'mean_square_per_room_in_dr']).astype('int')

    df.loc[df['Rooms'] == 0, 'Rooms'] \
        = (df.loc[df['Rooms'] == 0, 'Square']
           // df.loc[df['Rooms'] == 0, 'mean_square_per_room_in_dr']).astype('int')

    df.loc[df['Rooms'] == 0, 'Rooms'] = 1
    return df

# %% [markdown]
# ### Работаем с признакоми 'Square' и 'LifeSquare'

# %%
all_data.loc[all_data['Square'] > 200].nlargest(20, 'Square')
# Out:
#           Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 6977   11602          30      2  641.065186  638.163208           10.0     20
# 4262      28           9      2  604.705994         NaN            1.0     17
# 4690    2307         102      1  409.425171  410.639740           10.0      4
# 1982    5548          86      5  275.645294  233.949310           26.0     12
# 13217   4058          27      6  223.453690  104.113556           16.0      2
# 13909   1397          76      3  221.138763  118.055344            4.0     32
# 1981    7917          27      0  212.932358  211.231125            0.0      2
# 9910   16568          27      4  200.334534  201.627365           25.0      1
#
#        HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 6977           19       2019   0.000078         B         B        22
# 4262           18       1977   0.161532         B         B        25
# 4690            4       2016   0.238617         B         B        26
# 1982           37       2011   0.161976         B         A        31
# 13217           2       2017   0.041116         B         B        53
# 13909          48       2011   0.000000         B         B         7
# 1981            3       2008   0.211401         B         B         9
# 9910            2       2013   0.041116         B         B        53
#
#        Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 6977       6398       141        1046.0            3       23       B
# 4262       5648         1          30.0            2        4       B
# 4690       3889         6         705.0            3        6       B
# 1982       7010         5        4508.0            3        7       B
# 13217     14892         4           NaN            1        4       B
# 13909      1660        39        1786.0            1        5       B
# 1981       1892         0           NaN            0        1       B
# 9910      14892         4           NaN            1        4       B

# %%
sns.distplot(all_data['Square'], fit=norm)

mu, sigma = norm.fit(all_data['Square'])

plt.legend([f'Normal dist. ($\mu=$ {mu:.2f} и $\sigma=$ {sigma:.2f} )'])
plt.ylabel('Frequency')
plt.title('Square distribution')

# QQ-plot
fig = plt.figure()
res = stats.probplot(all_data['Square'], plot=plt)
plt.show()

# %%
plt.figure()
plt.scatter(range(all_data.shape[0]), np.sort(all_data.Square.values))
plt.xlabel('Count')
plt.ylabel('Square')
plt.show()

# %% [markdown]
# По всем грвфикам наблюдаем выбросы

# %%
def df_fix_square_manual(df):
    df.loc[df['Square'] > 400, 'Square'] = df.loc[df['Square'] > 400, 'Square'] / 10
    return df

# %%
def df_fix_square(df):
    info_by_district_id = df.groupby(['DistrictId', 'Rooms', 'HouseYear'], as_index=False).agg(
        {'Square': 'mean'}).rename(
        columns={'Square': 'mean_square_rooms_dr'})

    df = pd.merge(df, info_by_district_id, on=[
        'DistrictId', 'Rooms', 'HouseYear'], how='left')

    df.loc[abs(df['Square'] - df['mean_square_rooms_dr']) > 2 * sigma, 'Square'] \
        = df.loc[abs(df['Square'] - df['mean_square_rooms_dr']) > 2 * sigma, 'Rooms'] \
        * df.loc[abs(df['Square'] - df['mean_square_rooms_dr']) > 2 * sigma, 'mean_square_per_room_in_dr']
    return df

# %%
def prepare_lifesquare(df):
    df.loc[df['Square'] < df['LifeSquare'],
           'LifeSquare'] = df.loc[df['Square'] < df['LifeSquare'], 'Square']
    return df


def fillna_life_square(df):
    df['LifeSquare'] = df['LifeSquare'].fillna(df['LifeSquare'].mean())
    return df

# %% [markdown]
# ### Работаем с признаком 'KitchenSquare'

# %%
all_data[all_data['KitchenSquare'] > 32]
# Out:
#           Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 227    16395           2      3   79.722244   44.731220           72.0     12
# 551     1315           6      1   48.128113   45.023533           48.0     21
# 1064   14656          62      1   47.100719   46.447960         2014.0      4
# 1077    9690          27      1   40.081043   37.834965           37.0     18
# 1369    2371          27      2   68.841072   64.234955           66.0      4
# 1455   12507          54      2   79.810532   79.578964           78.0     10
# 1860    4265         161      2   53.216778   32.644859           53.0      7
# 1867    3267          58      3  138.980820  138.004593           43.0      2
# 2916   12390          72      3   97.490677   99.323555           96.0     22
# 2969    7441          62      3  114.734474  112.589081          112.0      3
# 3379   16781          27      1   36.138409   36.710541           36.0     19
# 3431    7111          27      2  139.070297   89.787666           42.0      5
# 4079    6508          23      2   67.146049   33.959152           63.0      5
# 4110     299          27      2   66.787521   64.616661           60.0     14
# 4142   15466          88      1   42.357487   44.779713           41.0     10
# 4588     448          48      1   41.186905    1.626502           41.0      2
# 4651   12552          58      3  116.405693  113.109650          112.0      3
# 5149   13703          42      1   38.071693   19.723547           73.0      9
# 5162   11739          27      2   61.070297   59.845093           58.0      8
# 5480   15781          10      1   35.813564   19.953993           35.0      6
# 5816    2271          27      1   43.292515   42.835644           40.0     12
# 5849   11624          46      1   42.983284   24.224436           37.0     15
# 5888   16593          52      2   64.859245         NaN           62.0     15
# 5904     673          27      1   54.418213   51.498581           51.0     10
# 6036   12666          34      2   60.603363    2.400832           58.0     14
# 6240    4966          96      3   78.445679   47.146755           75.0      9
# 7088    6569          27      1   38.220257   18.716856           84.0      4
# 7480   10546          62      1   46.013187   43.417042           43.0      4
# 8232    7162          34      2   56.738762   57.510395           54.0     26
# 8584   14679          81      1   32.276665   19.278395         1970.0      6
# 9111    6708          48      1   42.069359   22.487740           39.0      1
# 9889   12918          23      2   51.440464   53.134243           51.0      3
# 9895    2737          27      3  123.430069  125.806984          123.0      5
# 10040   5428          27      2   62.326042         NaN           61.0     12
# 10625   2249          62      1   77.157677   78.281761           34.0      5
# 10803   3747          23      5  139.045761   89.790276           42.0      1
# 10870  13736          27      1  141.540222   91.704803           42.0      3
# 11447   1968          27      2  138.039185   92.484100           42.0      3
# 11456   5260          73      3   69.358246   51.247581           65.0      6
# 11777   3341          62      3  112.114021  112.247841          112.0      3
# 11964  14594          11      2   42.795303   24.223770          620.0     11
# 12424  10662          29      1   25.956829   17.251768           33.0      5
# 13723   4483          62      1   41.951462   45.672138           41.0     13
# 13816  12612          27      2   60.988495   33.646725           60.0      5
# 13863   3194          29      2   43.926987   31.028708           44.0      6
# 13927   6568          78      1   46.827202   40.227013           40.0      5
# 14281   8015          27      1   66.099098   33.639610           62.0      3
# 14405   5199          27      2   59.054989   61.647530           57.0     13
# 14555  12640           6      2   54.629143   31.486307           97.0      4
#
#        HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 227            16       1987   0.130618         B         B        39
# 551             1       2013   0.243205         B         B         5
# 1064            1       2014   0.072158         B         B         2
# 1077           19       2019   0.211401         B         B         9
# 1369            2       2014   0.017647         B         B         2
# 1455           15       2014   0.006076         B         B        30
# 1860           17       1994   0.000699         B         B        14
# 1867            2       1977   0.437885         B         B        23
# 2916           25       2019   0.210473         B         B        11
# 2969            3       2015   0.072158         B         B         2
# 3379           19       2017   0.072158         B         B         2
# 3431            3       2016   0.014073         B         B         2
# 4079           17       2019   0.034656         B         B         0
# 4110           20       2015   0.017647         B         B         2
# 4142           19       2016   0.127376         B         B        43
# 4588            1       1977   0.041125         B         B        46
# 4651            3       2016   0.437885         B         B        23
# 5149           10       2006   0.158249         B         B        21
# 5162           17       2016   0.072158         B         B         2
# 5480           14       1971   0.282798         B         B        33
# 5816           11       2015   0.211401         B         B         9
# 5849           16       1983   0.188784         B         B        31
# 5888           17       1977   0.371149         B         B        34
# 5904           17       2017   0.072158         B         B         2
# 6036           22       1977   0.069753         B         B        53
# 6240           12       1977   0.041116         B         B        53
# 7088           17       2018   0.011654         B         B         4
# 7480           17       2019   0.072158         B         B         2
# 8232           25       2016   0.069753         B         B        53
# 8584            1       1977   0.006076         B         B        30
# 9111           10       2010   0.041125         B         B        46
# 9889           17       2017   0.005767         B         B         1
# 9895           10       2015   0.017647         B         B         2
# 10040          17       1977   0.072158         B         B         2
# 10625          24       2016   0.072158         B         B         2
# 10803           3       2015   0.014073         B         B         2
# 10870           3       2013   0.014073         B         B         2
# 11447           3       2016   0.014073         B         B         2
# 11456           6       1931   0.042032         B         B        37
# 11777           3       2017   0.072158         B         B         2
# 11964          14       1972   0.038693         B         B        28
# 12424           5       1973   0.069660         B         B        31
# 13723          17       2018   0.072158         B         B         2
# 13816          17       2013   0.072158         B         B         2
# 13863           5       1964   0.086885         B         B        10
# 13927          32       2007   0.219006         B         B        28
# 14281           7       2016   0.014058         B         B         1
# 14405          12       2016   0.211401         B         B         9
# 14555          17       2015   0.243205         B         B         5
#
#        Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 227       10418         9         900.0            1        9       B
# 551        1564         0         540.0            0        0       B
# 1064        629         1           NaN            0        0       A
# 1077       1892         0           NaN            0        1       B
# 1369        469         0           NaN            0        0       B
# 1455       5285         0         645.0            6        6       B
# 1860       3369        24        4129.0            0        3       B
# 1867       5735         3        1084.0            0        5       B
# 2916       2398         2        1994.0            3        0       B
# 2969        629         1           NaN            0        0       A
# 3379        629         1           NaN            0        0       A
# 3431        475         0           NaN            0        0       B
# 4079        168         0           NaN            0        0       B
# 4110        469         0           NaN            0        0       B
# 4142       8429         3           NaN            3        9       B
# 4588       9515         5           NaN            1       10       B
# 4651       5735         3        1084.0            0        5       B
# 5149       5731         0           NaN            1        0       B
# 5162        629         1           NaN            0        0       A
# 5480       8667         2           NaN            0        6       B
# 5816       1892         0           NaN            0        1       B
# 5849       6137         4           NaN            0        1       B
# 5888       7065         1         750.0            2        5       B
# 5904        629         1           NaN            0        0       A
# 6036      13670         4           NaN            1       11       B
# 6240      14892         4           NaN            1        4       B
# 7088        915         0           NaN            0        0       B
# 7480        629         1           NaN            0        0       A
# 8232      13670         4           NaN            1       11       B
# 8584       5285         0         645.0            6        6       B
# 9111       9515         5           NaN            1       10       B
# 9889        388         0           NaN            0        0       B
# 9895        469         0           NaN            0        0       B
# 10040       629         1           NaN            0        0       A
# 10625       629         1           NaN            0        0       A
# 10803       475         0           NaN            0        0       B
# 10870       475         0           NaN            0        0       B
# 11447       475         0           NaN            0        0       B
# 11456      6856        84        1940.0            2        5       B
# 11777       629         1           NaN            0        0       A
# 11964      6533         1        1015.0            2        5       B
# 12424      6119         4           NaN            1        2       B
# 13723       629         1           NaN            0        0       A
# 13816       629         1           NaN            0        0       A
# 13863      2277         2        1547.0            0        0       B
# 13927      6746         3           NaN            1        4       B
# 14281       290         0           NaN            0        0       B
# 14405      1892         0           NaN            0        1       B
# 14555      1564         0         540.0            0        0       B

# %%
def df_fix_kitchen_square_manual(df):
    df.loc[df['KitchenSquare'] > 32, 'KitchenSquare'] = df['KitchenSquare'].median()
    return df

# %% [markdown]
# ### Работаем с признаком 'HouseFloor'

# %%
all_data[all_data['HouseFloor'] == 0]
# Out:
#           Id  DistrictId  Rooms      Square  LifeSquare  KitchenSquare  Floor  \
# 7      11993          74      2   80.312927         NaN            0.0     14
# 23      6641          54      3  118.907608         NaN            0.0      2
# 26      4378          27      3  106.958870    0.641822            0.0     17
# 39      9371          23      2   60.503250         NaN            0.0     16
# 44     10521          38      3  104.211395  106.340401            0.0     20
# ...      ...         ...    ...         ...         ...            ...    ...
# 14856  10262          27      2   69.196442         NaN            0.0     10
# 14887  12116          88      3   89.549561         NaN            0.0     20
# 14892  16357          58      1   49.205978         NaN            0.0      4
# 14976   4723          95      1   45.542938         NaN            0.0      6
# 14998   4780          62      2   81.305222         NaN            0.0      4
#
#        HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 7               0       1977   0.075779         B         B         6
# 23              0       1977   0.006076         B         B        30
# 26              0       2018   0.072158         B         B         2
# 39              0       1977   0.034656         B         B         0
# 44              0       2017   0.060753         B         B        15
# ...           ...        ...        ...       ...       ...       ...
# 14856           0       1977   0.017647         B         B         2
# 14887           0       1977   0.127376         B         B        43
# 14892           0       1977   0.437885         B         B        23
# 14976           0       1977   0.000699         B         B        14
# 14998           0       1977   0.072158         B         B         2
#
#        Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 7          1437         3           NaN            0        2       B
# 23         5285         0         645.0            6        6       B
# 26          629         1           NaN            0        0       A
# 39          168         0           NaN            0        0       B
# 44         2787         2         520.0            0        7       B
# ...         ...       ...           ...          ...      ...     ...
# 14856       469         0           NaN            0        0       B
# 14887      8429         3           NaN            3        9       B
# 14892      5735         3        1084.0            0        5       B
# 14976      3369        24        4129.0            0        3       B
# 14998       629         1           NaN            0        0       A
#
# [400 rows x 19 columns]

# %%
def df_fix_house_floor_manual(df):
    df.loc[df['HouseFloor'] == 0, 'HouseFloor'] = df.loc[df['HouseFloor'] == 0, 'Floor']
    return df

# %%
df_fix_house_floor_manual(all_data)
all_data
# Out:
#           Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0      14038          35      2  47.981560   29.442751            6.0      7
# 1      15053          41      3  65.683640   40.049541            8.0      7
# 2       4765          53      2  44.947952   29.197611            0.0      8
# 3       5809          58      2  53.352982   52.731510            9.0      8
# 4      10783          99      1  39.649193   23.776169            7.0     11
# ...      ...         ...    ...        ...         ...            ...    ...
# 14995   8180          11      3  67.133911   50.809795            6.0      5
# 14996   4695           1      1  40.198471   21.807060           10.0     12
# 14997   5783          12      3  77.842178   48.282623            9.0     23
# 14998   4780          62      2  81.305222         NaN            0.0      4
# 14999  12504          30      2  60.555695         NaN            1.0     10
#
#        HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 0               9       1969   0.089040         B         B        33
# 1               9       1978   0.000070         B         B        46
# 2              12       1968   0.049637         B         B        34
# 3              17       1977   0.437885         B         B        23
# 4              12       1976   0.012339         B         B        35
# ...           ...        ...        ...       ...       ...       ...
# 14995           9       1973   0.000170         B         B        36
# 14996          17       2017   0.007122         B         B         1
# 14997          22       1989   0.090799         B         B        74
# 14998           4       1977   0.072158         B         B         2
# 14999          17       1977   0.000078         B         B        22
#
#        Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 0          7976         5           NaN            0       11       B
# 1         10309         1         240.0            1       16       B
# 2          7759         0         229.0            1        3       B
# 3          5735         3        1084.0            0        5       B
# 4          5776         1        2078.0            2        4       B
# ...         ...       ...           ...          ...      ...     ...
# 14995      5992         0           NaN            1        1       B
# 14996       264         0           NaN            0        1       B
# 14997     19083         2           NaN            5       15       B
# 14998       629         1           NaN            0        0       A
# 14999      6398       141        1046.0            3       23       B
#
# [15000 rows x 19 columns]

# %% [markdown]
# ### Работаем с признаком 'HouseYear'

# %%
all_data.loc[all_data['HouseYear'] > 2020]
# Out:
#          Id  DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 1497  10814         109      1  37.265072   20.239714            9.0      9
# 4189  11607         147      2  44.791836   28.360394            5.0      4
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 1497          12   20052011   0.136330         B         B        30
# 4189           9       4968   0.319809         B         B        25
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 1497      6141        10         262.0            3        6       B
# 4189      4756        16        2857.0            5        8       B

# %%
def df_fix_house_year_manual(df):
    df.loc[df['HouseYear'] == 20052011, 'HouseYear'] = int((2005 + 2011) / 2)
    df.loc[df['HouseYear'] == 4968, 'HouseYear'] = 1968
    return df

# %% [markdown]
# ### Обработка пропусков

# %%
def df_del_missing(df):
    df_dm = df.isnull().sum()

    df_dm = df_dm.drop(df_dm[df_dm == 0].index)
    df_dm = list(df_dm.index)
    df.drop(df_dm, axis=1, inplace=True)
    return df

# %% [markdown]
# ### Исследуем целевую переменную 'Price'

# %%
sns.distplot(train['Price'], fit=norm)

mu, sigma = norm.fit(train['Price'])

plt.legend(
    [f'Normal dist. ($\mu=$ {mu:.2f} and $\sigma=$ {sigma:.2f} )'], loc='best'
)
plt.ylabel('Frequency')
plt.title('Price distribution')

# QQ-plot
fig = plt.figure()
res = stats.probplot(train['Price'], plot=plt)
plt.show()

# %%
plt.figure()
plt.scatter(range(train.shape[0]), np.sort(train.Price.values))
plt.xlabel('index', fontsize=12)
plt.ylabel('price', fontsize=12)
plt.show()

# %% [markdown]
# Рассмотрим логарифмическое распределение целевой переменной

# %%
price_log = np.log1p(train['Price'])
sns.distplot(price_log, fit=norm)

mu, sigma = norm.fit(train['Price'])

plt.legend(
    [f'Normal dist. ($\mu=$ {mu:.2f} and $\sigma=$ {sigma:.2f} )'], loc='best'
)
plt.ylabel('Frequency')
plt.title('Price distribution')

# QQ-plot
fig = plt.figure()
res = stats.probplot(price_log, plot=plt)
plt.show()

# %%
plt.figure()
plt.scatter(range(train.shape[0]), np.sort(price_log.values))
plt.xlabel('index', fontsize=12)
plt.ylabel('price', fontsize=12)
plt.show()

# %% [markdown]
# Никаких серьезных отклонений в стоимости квартир не наблюдается

# %% [markdown]
# #### Рассмотрим стоимость квартир в зависимости от года постройки дома

# %%
plt.figure(figsize=(18, 6))
sns.barplot(train['HouseYear'], train['Price'])
plt.xticks(rotation=90)
plt.title('Distribution of variable House Year')
# Out:
# Text(0.5, 1.0, 'Distribution of variable House Year')

# %% [markdown]
# Наблюдается большой расброс цен на дома старой постройки, а также хорошо послеживается  зависимость стоимости квартиры от года построики дома (можно попробовать разбить на кластеры)

# %% [markdown]
# #### Рассмотрим стоимость квартир в зависимости от района

# %%
plt.figure(figsize=(18, 6))
sns.barplot(train['DistrictId'], train['Price'])
plt.xticks(rotation=90)
plt.title('Distribution of variable District Id')
# Out:
# Text(0.5, 1.0, 'Distribution of variable District Id')

# %% [markdown]
# Есть не значительная зависимость стоимости картиры от района

# %% [markdown]
# ### Построим матрицу корреляций

# %%
corrmat = train.loc[:, train.columns != 'Id'].corr()
plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, annot=True, linewidths=.5, cmap='GnBu')

# %%
corrmat = train.loc[:, train.columns != 'Id'].corrwith(
    train['Price']).abs().sort_values(ascending=False)[1:]
plt.bar(corrmat.index, corrmat.values)
plt.title('Correlation to Price')
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ## Построение новых признаков

# %% [markdown]
# ### Применим метод кластаризации

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering

# %%
scaler = StandardScaler()

# %%
train_cluster = train.copy()

# %%
train_cluster = df_fix_house_year_manual(train_cluster)

# %%
train_cluster_scaled = pd.DataFrame(scaler.fit_transform(
    train_cluster.loc[:, ['HouseYear', 'Price']]), columns=['HouseYear', 'Price'])

# %%
inertias = []

for i in range(2, 10):
    temp_model = KMeans(n_clusters=i, random_state=42)
    temp_model.fit(train_cluster_scaled)
    temp_inertia = temp_model.inertia_
    inertias.append(temp_inertia)

plt.plot(range(2, 10), inertias)
plt.title('Inertia')
# Out:
# Text(0.5, 1.0, 'Inertia')

# %%
plt.scatter(train_cluster_scaled['HouseYear'], train_cluster_scaled['Price'])
plt.xlabel('HouseYear')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# #### Воспользуемся методом Агломеративной кластеризации

# %%
agglomerative_clustering_model = AgglomerativeClustering(n_clusters=5)

# %%
train_cluster['cluster_year'] = agglomerative_clustering_model.fit_predict(
    train_cluster_scaled)

# %%
plt.scatter(train_cluster['HouseYear'],
            train_cluster['Price'], c=train_cluster['cluster_year'])
plt.xlabel('HouseYear')
plt.ylabel('Price')
plt.title('Train')
# Out:
# Text(0.5, 1.0, 'Train')

# %%
def add_cluster_year(df):
    df_scaled = pd.DataFrame(scaler.fit_transform(
        df.loc[:, ['HouseYear']]), columns=['HouseYear'])
    df['cluster_year'] = agglomerative_clustering_model.fit_predict(df_scaled)
    return df

# %% [markdown]
# #### Средняя  стоимость квартиры и средняя стоимость квартиры в зависимости от района

# %%
def add_mean_price(df, df_train=train):
    price = df_train['Price'].mean()
    price_mean_by_rooms = df_train.groupby(['Rooms'], as_index=False).agg({'Price': 'mean'}).\
        rename(columns={'Price': 'mean_price_by_rooms'})

    price_mean_by_distr_rooms = df_train.groupby(['DistrictId', 'Rooms'], as_index=False).agg({'Price': 'mean'}).\
        rename(columns={'Price': 'mean_price_dr'})

    df = pd.merge(df, price_mean_by_distr_rooms, on=[
                  'DistrictId', 'Rooms'], how='left')
    df = pd.merge(df, price_mean_by_rooms, on='Rooms', how='left')
    df['mean_price_dr'] = df['mean_price_dr'].fillna(df['mean_price_by_rooms'])
    df['mean_price_dr'] = df['mean_price_dr'].fillna(price)
    df['mean_price_by_rooms'] = df['mean_price_by_rooms'].fillna(price)
    return df

# %% [markdown]
# #### Работаем с признаком 'DistrictId'

# %%
def add_distr_info(df):
    distr_info = df['DistrictId'].value_counts().reset_index().\
        rename(columns={"index": "DistrictId", "DistrictId": 'large_district'})
    df = pd.merge(df, distr_info, on='DistrictId', how='left')
    df = df.drop('DistrictId', axis=1)
    df['large_district'] = df['large_district'].fillna(1)
    
    return df

# %% [markdown]
# ## Приступаем к созданию модели

# %% [markdown]
# ### Создаем функции обработки данных

# %%
def data_prepare(df, df_train=train):
    df = df_fix_room(df)
    df = df_fix_square_manual(df)
    df = df_fix_square(df)
    df = prepare_lifesquare(df)
    df = fillna_life_square(df)
    df = df_fix_kitchen_square_manual(df)
    df = df_fix_house_floor_manual(df)
    df = df_fix_house_year_manual(df)
    df = df_del_missing(df)
    df = add_cluster_year(df)
    df = add_mean_price(df, df_train)
    df = add_distr_info(df)
    df = pd.get_dummies(df)
    df.drop('mean_square_per_room_in_dr', axis=1, inplace=True)
    df.drop('mean_square_rooms_dr', axis=1, inplace=True)
    optimizing_df(df)
    return df


def model_test(model, name, test, valid):
    model_pred = model.predict(test)
    r2_ = r2(valid, model_pred)
    mae_ = mae(valid, model_pred)
    plt.scatter(valid, model_pred)
    plt.xlabel("Real values")
    plt.ylabel("Predicted values")
    plt.title(name)
    plt.legend([f'R2 = {r2_:.4f}\nMAE = {mae_:.2f}'], loc="lower right", frameon=True)
    plt.show()

# %% [markdown]
# ### Подгружаем библиотеки

# %%
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.metrics import r2_score as r2, mean_absolute_error as mae
from sklearn.model_selection import train_test_split, GridSearchCV, KFold
from lightgbm import LGBMRegressor

# %% [markdown]
# ###  Приступаем к обработке данных

# %%
train.columns
# Out:
# Index(['Id', 'DistrictId', 'Rooms', 'Square', 'LifeSquare', 'KitchenSquare',
#        'Floor', 'HouseFloor', 'HouseYear', 'Ecology_1', 'Ecology_2',
#        'Ecology_3', 'Social_1', 'Social_2', 'Social_3', 'Healthcare_1',
#        'Helthcare_2', 'Shops_1', 'Shops_2', 'Price'],
#       dtype='object')

# %%
features = ['DistrictId', 'Rooms', 'Square', 'LifeSquare', 'KitchenSquare',
       'Floor', 'HouseFloor', 'HouseYear', 'Ecology_1', 'Ecology_2',
       'Ecology_3', 'Social_1', 'Social_2', 'Social_3', 'Healthcare_1',
       'Helthcare_2', 'Shops_1', 'Shops_2']

target = 'Price'

# %%
train[features]
# Out:
#       DistrictId  Rooms     Square  LifeSquare  KitchenSquare  Floor  \
# 0             35      2  47.981560   29.442751            6.0      7
# 1             41      3  65.683640   40.049541            8.0      7
# 2             53      2  44.947952   29.197611            0.0      8
# 3             58      2  53.352982   52.731510            9.0      8
# 4             99      1  39.649193   23.776169            7.0     11
# ...          ...    ...        ...         ...            ...    ...
# 9995          32      2  50.401787   30.476204            5.0      6
# 9996          18      1  41.521545   20.539215            9.0     13
# 9997          27      1  47.939007         NaN            1.0     12
# 9998          75      2  43.602562   33.840149            8.0      1
# 9999         128      1  38.666645   21.157875            8.0      7
#
#       HouseFloor  HouseYear  Ecology_1 Ecology_2 Ecology_3  Social_1  \
# 0              9       1969   0.089040         B         B        33
# 1              9       1978   0.000070         B         B        46
# 2             12       1968   0.049637         B         B        34
# 3             17       1977   0.437885         B         B        23
# 4             12       1976   0.012339         B         B        35
# ...          ...        ...        ...       ...       ...       ...
# 9995           5       1968   0.135650         B         B        46
# 9996          13       2000   0.000000         B         B        30
# 9997          16       2015   0.072158         B         B         2
# 9998           5       1961   0.307467         B         A        30
# 9999          17       1990   0.000000         B         B        27
#
#       Social_2  Social_3  Healthcare_1  Helthcare_2  Shops_1 Shops_2
# 0         7976         5           NaN            0       11       B
# 1        10309         1         240.0            1       16       B
# 2         7759         0         229.0            1        3       B
# 3         5735         3        1084.0            0        5       B
# 4         5776         1        2078.0            2        4       B
# ...        ...       ...           ...          ...      ...     ...
# 9995      7960         6         350.0            3       11       B
# 9996      5562         0           NaN            0        5       A
# 9997       629         1           NaN            0        0       A
# 9998      5048         9         325.0            2        5       B
# 9999      4798         0          30.0            2        8       B
#
# [10000 rows x 18 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    train[features], train[target], test_size=0.3, shuffle=True, random_state=42)

# %%
X_train = data_prepare(X_train, train)
X_test = data_prepare(X_test, train)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7000 entries, 0 to 6999
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rooms                7000 non-null   uint8
#  1   Square               7000 non-null   float32
#  2   LifeSquare           7000 non-null   float32
#  3   KitchenSquare        7000 non-null   float32
#  4   Floor                7000 non-null   uint8
#  5   HouseFloor           7000 non-null   uint8
#  6   HouseYear            7000 non-null   uint16
#  7   Ecology_1            7000 non-null   float32
#  8   Social_1             7000 non-null   uint8
#  9   Social_2             7000 non-null   uint16
#  10  Social_3             7000 non-null   uint8
#  11  Helthcare_2          7000 non-null   uint8
#  12  Shops_1              7000 non-null   uint8
#  13  cluster_year         7000 non-null   uint8
#  14  mean_price_dr        7000 non-null   float32
#  15  mean_price_by_rooms  7000 non-null   float32
#  16  large_district       7000 non-null   uint16
#  17  Ecology_2_A          7000 non-null   uint8
#  18  Ecology_2_B          7000 non-null   uint8
#  19  Ecology_3_A          7000 non-null   uint8
#  20  Ecology_3_B          7000 non-null   uint8
#  21  Shops_2_A            7000 non-null   uint8
#  22  Shops_2_B            7000 non-null   uint8
# dtypes: float32(6), uint16(3), uint8(14)
# memory usage: 355.5 KB

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rooms                3000 non-null   uint8
#  1   Square               3000 non-null   float32
#  2   LifeSquare           3000 non-null   float32
#  3   KitchenSquare        3000 non-null   float32
#  4   Floor                3000 non-null   uint8
#  5   HouseFloor           3000 non-null   uint8
#  6   HouseYear            3000 non-null   uint16
#  7   Ecology_1            3000 non-null   float32
#  8   Social_1             3000 non-null   uint8
#  9   Social_2             3000 non-null   uint16
#  10  Social_3             3000 non-null   uint8
#  11  Helthcare_2          3000 non-null   uint8
#  12  Shops_1              3000 non-null   uint8
#  13  cluster_year         3000 non-null   uint8
#  14  mean_price_dr        3000 non-null   float32
#  15  mean_price_by_rooms  3000 non-null   float32
#  16  large_district       3000 non-null   uint16
#  17  Ecology_2_A          3000 non-null   uint8
#  18  Ecology_2_B          3000 non-null   uint8
#  19  Ecology_3_A          3000 non-null   uint8
#  20  Ecology_3_B          3000 non-null   uint8
#  21  Shops_2_A            3000 non-null   uint8
#  22  Shops_2_B            3000 non-null   uint8
# dtypes: float32(6), uint16(3), uint8(14)
# memory usage: 152.3 KB

# %% [markdown]
# ### Gradient Boosting Regressor

# %%
gradient_boosting_regressor_model = GradientBoostingRegressor()
gradient_boosting_regressor_model.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=3,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
model_test(gradient_boosting_regressor_model,
           'Gradient Boosting Regressor', X_test, y_test)

# %%
params = {
    'n_estimators':[50, 100, 200, 300, 400], 
    'max_depth':[3, 5, 7, 10]
}

g_model = GridSearchCV(gradient_boosting_regressor_model, params, scoring='r2', cv=KFold(n_splits=3, random_state=42, shuffle=True), n_jobs=-1)
g_model.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=KFold(n_splits=3, random_state=42, shuffle=True),
#              error_score=nan,
#              estimator=GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0,
#                                                  criterion='friedman_mse',
#                                                  init=None, learning_rate=0.1,
#                                                  loss='ls', max_depth=3,
#                                                  max_features=None,
#                                                  max_leaf_nodes=None,
#                                                  min_impurity_decrease=0.0,
#                                                  min_impurity_split=None,
#                                                  min_samples_leaf=1,
#                                                  min_samples_split=2,
#                                                  min_weigh...ion_leaf=0.0,
#                                                  n_estimators=100,
#                                                  n_iter_no_change=None,
#                                                  presort='deprecated',
#                                                  random_state=None,
#                                                  subsample=1.0, tol=0.0001,
#                                                  validation_fraction=0.1,
#                                                  verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'max_depth': [3, 5, 7, 10],
#                          'n_estimators': [50, 100, 200, 300, 400]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='r2', verbose=0)

# %%
g_model.best_params_
# Out:
# {'max_depth': 5, 'n_estimators': 100}

# %%
gradient_boosting_regressor_model = GradientBoostingRegressor(n_estimators=100, max_depth=5, random_state=42)
gradient_boosting_regressor_model.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(alpha=0.9, ccp_alpha=0.0, criterion='friedman_mse',
#                           init=None, learning_rate=0.1, loss='ls', max_depth=5,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=100,
#                           n_iter_no_change=None, presort='deprecated',
#                           random_state=42, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
model_test(gradient_boosting_regressor_model,
           'Gradient Boosting Regressor', X_test, y_test)

# %% [markdown]
# ## Предсказание цены для квартир из тестового датасета

# %%
test = data_prepare(test)

# %%
test_features = list(X_train.columns)

# %%
test[test_features].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 0 to 4999
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Rooms                5000 non-null   uint8
#  1   Square               5000 non-null   float32
#  2   LifeSquare           5000 non-null   float32
#  3   KitchenSquare        5000 non-null   float32
#  4   Floor                5000 non-null   uint8
#  5   HouseFloor           5000 non-null   uint8
#  6   HouseYear            5000 non-null   uint16
#  7   Ecology_1            5000 non-null   float32
#  8   Social_1             5000 non-null   uint8
#  9   Social_2             5000 non-null   uint16
#  10  Social_3             5000 non-null   uint8
#  11  Helthcare_2          5000 non-null   uint8
#  12  Shops_1              5000 non-null   uint8
#  13  cluster_year         5000 non-null   uint8
#  14  mean_price_dr        5000 non-null   float32
#  15  mean_price_by_rooms  5000 non-null   float32
#  16  large_district       5000 non-null   uint16
#  17  Ecology_2_A          5000 non-null   uint8
#  18  Ecology_2_B          5000 non-null   uint8
#  19  Ecology_3_A          5000 non-null   uint8
#  20  Ecology_3_B          5000 non-null   uint8
#  21  Shops_2_A            5000 non-null   uint8
#  22  Shops_2_B            5000 non-null   uint8
# dtypes: float32(6), uint16(3), uint8(14)
# memory usage: 253.9 KB

# %%
test['Price'] = gradient_boosting_regressor_model.predict(test[test_features])

# %%
price_log = np.log1p(test['Price'])
sns.distplot(price_log, fit=norm)

mu, sigma = norm.fit(test['Price'])

plt.legend(
    [f'Normal dist. ($\mu=$ {mu:.2f} and $\sigma=$ {sigma:.2f} )'], loc='best'
)
plt.ylabel('Frequency')
plt.title('Price distribution')

# QQ-plot
fig = plt.figure()
res = stats.probplot(price_log, plot=plt)
plt.show()

# %%
test[['Id', 'Price']].to_csv('NSharovatov_predictions.csv', index=None)
